# %%
import talib
import vectorbt as vbt
import pandas as pd

from datetime import datetime, timedelta
import yfinance as yf

import matplotlib.pyplot as plt

from utils import *
from myInds import *

# %%
def daily_report(ticker, tf='15m', days=5, stratName = 'obv'):
    ticker = ticker.upper()
    if (tf[-1] == 'd'):
        trading_days = max(50, days)
    else:
        trading_days = days
        
    end_date = datetime.now()
    start_date = end_date - timedelta(days=trading_days)
    holds = []
    buys = []
    sells = []
#     start_date = datetime(2022, 3, 1) # Adjust as needed
#     end_date = datetime(2023, 3, 17)   # Adjust as needed
    pf, entries, exits = strategy_trends(ticker, startdate = start_date, enddate = end_date, tf = tf, flag_obv='close', flag_sig='open', straSE = stratName)
    mark_ticker(ticker, holds, buys, sells, entries, exits, tf=tf)

    print("*****************************************")
    print("*****************************************")
    print(f"{stratName.upper()} study analsis ")
    print("------------------------------")
    print("holds:", holds)
    print("buys:", buys)
    print("sells:", sells)
    print("*****************************************")
    print("*****************************************")
    print(pf.stats())
    fig = pf.plot()
    fig.layout.xaxis.type = 'category'
    fig.layout.xaxis2.type = 'category'
    fig.layout.xaxis3.type = 'category'
    fig.show()

# %%
ticker =  'tsla'
# interval = '15m'
# duration = 5

interval = '1d'
duration = 90

strategy = 'obv'
daily_report(ticker, tf=interval, days=duration, stratName = strategy)
# Out:
# [*********************100%***********************]  1 of 1 completed
# sell 2023-10-09 00:00:00-04:00
# *****************************************
# *****************************************
# OBV study analsis
# ------------------------------
# holds: []
# buys: []
# sells: ['TSLA']
# *****************************************
# *****************************************
# Start                         2023-07-11 00:00:00-04:00
# End                           2023-10-09 00:00:00-04:00
# Period                                               64
# Start Value                                       100.0
# End Value                                    171.587255
#                                         ...
# Avg Losing Trade [%]                          -1.479213
# Avg Winning Trade Duration                     1.846154
# Avg Losing Trade Duration                           1.0
# Profit Factor                                 40.743099
# Expectancy                                       4.6524
# Length: 24, dtype: object
# /home/steven/anaconda3/lib/python3.9/site-packages/vectorbt/generic/stats_builder.py:396: UserWarning:
#
# Metric 'sharpe_ratio' requires frequency to be set
#
# /home/steven/anaconda3/lib/python3.9/site-packages/vectorbt/generic/stats_builder.py:396: UserWarning:
#
# Metric 'calmar_ratio' requires frequency to be set
#
# /home/steven/anaconda3/lib/python3.9/site-packages/vectorbt/generic/stats_builder.py:396: UserWarning:
#
# Metric 'omega_ratio' requires frequency to be set
#
# /home/steven/anaconda3/lib/python3.9/site-packages/vectorbt/generic/stats_builder.py:396: UserWarning:
#
# Metric 'sortino_ratio' requires frequency to be set
# <div>                            <div id="13692b72-77e0-476c-8408-f98b560d683f" class="plotly-graph-div" style="height:960px; width:750px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("13692b72-77e0-476c-8408-f98b560d683f")) {                    Plotly.newPlot(                        "13692b72-77e0-476c-8408-f98b560d683f",                        [{"line":{"color":"#1f77b4"},"name":"Close","showlegend":true,"x":["2023-07-11T00:00:00-04:00","2023-07-12T00:00:00-04:00","2023-07-13T00:00:00-04:00","2023-07-14T00:00:00-04:00","2023-07-17T00:00:00-04:00","2023-07-18T00:00:00-04:00","2023-07-19T00:00:00-04:00","2023-07-20T00:00:00-04:00","2023-07-21T00:00:00-04:00","2023-07-24T00:00:00-04:00","2023-07-25T00:00:00-04:00","2023-07-26T00:00:00-04:00","2023-07-27T00:00:00-04:00","2023-07-28T00:00:00-04:00","2023-07-31T00:00:00-04:00","2023-08-01T00:00:00-04:00","2023-08-02T00:00:00-04:00","2023-08-03T00:00:00-04:00","2023-08-04T00:00:00-04:00","2023-08-07T00:00:00-04:00","2023-08-08T00:00:00-04:00","2023-08-09T00:00:00-04:00","2023-08-10T00:00:00-04:00","2023-08-11T00:00:00-04:00","2023
    core = ["TSLA", "GOOG", "MSFT", "NVDA","NFLX","AAPL","BLK"]
    energy = ["GUSH", "CF", "EQT","OXY","SEDG"]
    semi = ["QCOM","LRCX","ASML","AMD","SOXL","TSM"]
    index = ["SPY","QQQ","TQQQ", "SQQQ","IWM"]
    fin = ["BLK","BX","TLT"]
    hot = ["SHOP","FSLY","U","ZM"]
    btc = ["COIN","BTC-USD","MSTR","ETH-USD"]
    software = ["ADBE","MSFT","PLTR"]
    base = ["COST","HD","KO","MCD","PFE","UNH"]
    bio = ["XBI"]
    cloud = ["OKTA","DDOG","DASH","NOW"]
    random = ["NKX","DOG", "GTLB","RBLX","FSLY", "SNAP", "ROKU"]
    tradition = ["AAL"]
    tickers = core + semi + index
    return tickers

def daily_core_report(tickers, tf):
    # + energy + fin + hot + btc + software + bio + base + cloud + random + tradition
    # ["GOOG", "TSLA","GUSH","EQT","COIN","ENPH","AAPL","SHOP","NVDA","BX","BLK","LRCX","TSM","TLT", "TAN"]
    watch = retrieve_data(tickers, tf=tf)
    holds = []
    buys = []
    sells = []

    trading_days = 10
    days = 15
    # df, trendy = process_data(watch, ticker, tf, duration=period)
    # df, trendy = process_data(watch, ticker, tf, duration=period)
    straSE = 'obv'
    flag = 'open'

    if (tf[-1] == 'd'):
        trading_days = max(50, days)
    else:
        trading_days = days

    end_date = datetime.now()
    start_date = end_date - timedelta(days=trading_days)

    # for x in sgroups.get('sp500'):
    trading_days=1
    for x in tickers:
        pf, entries, exits = strategy_trends(x, startdate = start_date, enddate = end_date, tf = tf, flag_obv='close', flag_sig='open', straSE = straSE)
        print(x)
        mark_ticker(x, holds, buys, sells, entries, exits, tf='1d')
        
    print("*****************************************")
    print("*****************************************")
    print(f"{straSE.upper()} study analsis of {flag} prices. \nPERIOD: {start_date} to {end_date}, \nINTERVAL: {tf}")
    print("------------------------------")
    print("Holds:")
    iteminrow=20
    for i in range(round(len(holds)/iteminrow)+1):
        print (", ".join(holds[i*iteminrow:(i+1)*iteminrow]))
    print("buys:")
    for i in range(round(len(buys)/iteminrow)+1):
        print (", ".join(buys[i*iteminrow:(i+1)*iteminrow]))
    print("sells:")
    for i in range(round(len(sells)/iteminrow)+1):
        print (", ".join(sells[i*iteminrow:(i+1)*iteminrow]))
    print("*****************************************")
    print("*****************************************")

# %%
tickers = init()
daily_core_report(tickers, tf='1d')
# Out:
# [!] Loading All: TSLA, GOOG, MSFT, NVDA, NFLX, AAPL, BLK, QCOM, LRCX, ASML, AMD, SOXL, TSM, SPY, QQQ, TQQQ, SQQQ, IWM
# /home/steven/av_data/data/TSLA_1d.csv
# [i] Loaded TSLA[1d]: TSLA_1d.csv
# [i] Runtime: 99.2454 ms (0.0992 s)
# /home/steven/av_data/data/GOOG_1d.csv
# [i] Loaded GOOG[1d]: GOOG_1d.csv
# [i] Runtime: 95.5017 ms (0.0955 s)
# /home/steven/av_data/data/MSFT_1d.csv
# [i] Loaded MSFT[1d]: MSFT_1d.csv
# [i] Runtime: 98.4550 ms (0.0985 s)
# /home/steven/av_data/data/NVDA_1d.csv
# [i] Loaded NVDA[1d]: NVDA_1d.csv
# [i] Runtime: 100.1542 ms (0.1002 s)
# /home/steven/av_data/data/NFLX_1d.csv
# [i] Loaded NFLX[1d]: NFLX_1d.csv
# [i] Runtime: 100.5058 ms (0.1005 s)
# /home/steven/av_data/data/AAPL_1d.csv
# [i] Loaded AAPL[1d]: AAPL_1d.csv
# [i] Runtime: 101.6474 ms (0.1016 s)
# /home/steven/av_data/data/BLK_1d.csv
# [i] Loaded BLK[1d]: BLK_1d.csv
# [i] Runtime: 101.2344 ms (0.1012 s)
# /home/steven/av_data/data/QCOM_1d.csv
# [i] Loaded QCOM[1d]: QCOM_1d.csv
# [i] Runtime: 103.1028 ms (0.1031 s)
# /home/steven/av_data/data/LRCX_1d.csv
# [i] Loaded LRCX[1d]: LRCX_1d.csv
# [i] Runtime: 99.8720 ms (0.0999 s)
# /home/steven/av_data/data/ASML_1d.csv
# [i] Loaded ASML[1d]: ASML_1d.csv
# [i] Runtime: 99.3081 ms (0.0993 s)
# /home/steven/av_data/data/AMD_1d.csv
# [i] Loaded AMD[1d]: AMD_1d.csv
# [i] Runtime: 99.7289 ms (0.0997 s)
# /home/steven/av_data/data/SOXL_1d.csv
# [i] Loaded SOXL[1d]: SOXL_1d.csv
# [i] Runtime: 99.7073 ms (0.0997 s)
# /home/steven/av_data/data/TSM_1d.csv
# [i] Loaded TSM[1d]: TSM_1d.csv
# [i] Runtime: 107.8175 ms (0.1078 s)
# /home/steven/av_data/data/SPY_1d.csv
# [i] Loaded SPY[1d]: SPY_1d.csv
# [i] Runtime: 104.8414 ms (0.1048 s)
# /home/steven/av_data/data/QQQ_1d.csv
# [i] Loaded QQQ[1d]: QQQ_1d.csv
# [i] Runtime: 102.2471 ms (0.1022 s)
# /home/steven/av_data/data/TQQQ_1d.csv
# [i] Loaded TQQQ[1d]: TQQQ_1d.csv
# [i] Runtime: 101.7752 ms (0.1018 s)
# /home/steven/av_data/data/SQQQ_1d.csv
# [i] Loaded SQQQ[1d]: SQQQ_1d.csv
# [i] Runtime: 102.3611 ms (0.1024 s)
# /home/steven/av_data/data/IWM_1d.csv
# [i] Loaded IWM[1d]: IWM_1d.csv
# [i] Runtime: 102.4090 ms (0.1024 s)
# [*********************100%***********************]  1 of 1 completed
# TSLA
# sell 2023-10-09 00:00:00-04:00
# [*********************100%***********************]  1 of 1 completed
# GOOG
# buy 2023-10-09 00:00:00-04:00
# [*********************100%***********************]  1 of 1 completed
# MSFT
# buy 2023-10-09 00:00:00-04:00
# [*********************100%***********************]  1 of 1 completed
# NVDA
# sell 2023-10-09 00:00:00-04:00
# [*********************100%***********************]  1 of 1 completed
# NFLX
# buy 2023-10-09 00:00:00-04:00
# [*********************100%***********************]  1 of 1 completed
# AAPL
# buy 2023-10-09 00:00:00-04:00
# [*********************100%***********************]  1 of 1 completed
# BLK
# sell 2023-10-09 00:00:00-04:00
# [*********************100%***********************]  1 of 1 completed
# QCOM
# buy 2023-10-09 00:00:00-04:00
# [*********************100%***********************]  1 of 1 completed
# LRCX
# sell 2023-10-09 00:00:00-04:00
# [*********************100%***********************]  1 of 1 completed
# ASML
# sell 2023-10-09 00:00:00-04:00
# [*********************100%***********************]  1 of 1 completed
# AMD
# sell 2023-10-09 00:00:00-04:00
# [*********************100%***********************]  1 of 1 completed
# SOXL
# sell 2023-10-09 00:00:00-04:00
# [*********************100%***********************]  1 of 1 completed
# TSM
# buy 2023-10-09 00:00:00-04:00
# [*********************100%***********************]  1 of 1 completed
# SPY
# buy 2023-10-09 00:00:00-04:00
# [*********************100%***********************]  1 of 1 completed
# QQQ
# buy 2023-10-09 00:00:00-04:00
# [*********************100%***********************]  1 of 1 completed
# TQQQ
# buy 2023-10-09 00:00:00-04:00
# [*********************100%***********************]  1 of 1 completed
# SQQQ
# sell 2023-10-09 00:00:00-04:00
# [*********************100%***********************]  1 of 1 completed
# IWM
# buy 2023-10-09 00:00:00-04:00
# *****************************************
# *****************************************
# OBV study analsis of open prices.
# PERIOD: 2023-08-20 18:28:49.844592 to 2023-10-09 18:28:49.844592,
# INTERVAL: 1d
# ------------------------------
# Holds:
#
# buys:
# GOOG, MSFT, NFLX, AAPL, QCOM, TSM, SPY, QQQ, TQQQ, IWM
# sells:
# TSLA, NVDA, BLK, LRCX, ASML, AMD, SOXL, SQQQ
# *****************************************
# *****************************************
